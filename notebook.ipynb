# %%
import linecache
pl = int(linecache.getline('e_elaborate.in.txt', 1))*2+1
print(pl)
# Out:
# 9973

# %% [markdown]
# yaha se

# %%
hi = open("/content/e_elaborate.in.txt","r")
list_indi = []


def find_ingerdiants(list_indi):

  for i in hi:
    if len(i)>2:
      k = i.split()
      for j in k:
        if len(j)>2:

          if j not in list_indi:
            list_indi.append(j)



find_ingerdiants(list_indi)
print(len(list_indi))
# Out:
# 10001

# %%
score_indi = []
def score(list_indi):


  for s in range(0,len(list_indi)):

    x=0
    like=0
    dislike=0
    hello = open("/content/e_elaborate.in.txt","r")
    for i in hello:

      x+=1

      if len(i)>2:
        k = i.split()

        for j in k:

          if list_indi[s] == j:

            if x%2 == 0:
              like+=1

            else:
              dislike+=1


    score_indi.append(like-dislike)


score(list_indi)



str1=""
sum=0
for i in range(len(score_indi)):

  if score_indi[i]>100:
    sum = sum+score_indi[i]
    str1= str1+" "+list_indi[i]
print(sum,str1)
# Out:
# 0

# %% [markdown]
# End

# %%
hi = open("/content/b_basic.in.txt","r")
list_indi = []


def find_ingerdiants(list_indi):

  for i in hi:
    if len(i)>2:
      k = i.split()
      for j in k:
        if len(j)>2:

          if j not in list_indi:
            list_indi.append(j)



find_ingerdiants(list_indi)


score_indi = []
def score(list_indi):


  for s in range(0,len(list_indi)):

    x=0
    like=0
    dislike=0
    hello = open("/content/b_basic.in.txt","r")
    for i in hello:

      x+=1

      if len(i)>2:
        k = i.split()

        for j in k:

          if list_indi[s] == j:

            if x%2 == 0:
              like+=1

            else:
              dislike+=1


    score_indi.append(like-dislike)


score(list_indi)

str1=""
sum=0
for i in range(len(score_indi)):

  if score_indi[i]>0:
    sum = sum+score_indi[i]
    str1= str1+" "+list_indi[i]
print(sum,str1)
# Out:
# 10  akuof byyii dlust luncl vxglq xveqd

# %%
hi = open("/content/e_elaborate.in.txt","r")
list_indi = []


def find_ingerdiants(list_indi):

  for i in hi:
    if len(i)>2:
      k = i.split()
      for j in k:
        if len(j)>2:

          if j not in list_indi:
            list_indi.append(j)



find_ingerdiants(list_indi)


score_indi = []
def score(list_indi):


  for s in range(0,len(list_indi)):

    x=0
    like=0
    dislike=0
    hello = open("/content/e_elaborate.in.txt","r")
    for i in hello:

      x+=1

      if len(i)>2:
        k = i.split()

        for j in k:

          if list_indi[s] == j:

            if x%2 == 0:
              like+=1

            else:
              dislike+=1


    score_indi.append(like-dislike)


score(list_indi)

str1=""
sum=0
for i in range(len(score_indi)):

  if score_indi[i]>0:
    sum = sum+score_indi[i]
    str1= str1+" "+list_indi[i]
print(sum,str1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-09352b66e24c> in <module>()
#      50
#      51
# ---> 52 score(list_indi)
#      53
#      54 str1=""
#
# <ipython-input-11-09352b66e24c> in score(list_indi)
#      38         for j in k:
#      39
# ---> 40           if list_indi[s] == j:
#      41
#      42             if x%2 == 0:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/e_elaborate.in.txt")
df
# Out:
#                                                    4986
# 0     5 ingredient9922 ingredient3341 ingredient7670...
# 1                                      1 ingredient4654
# 2     5 ingredient2920 ingredient1643 ingredient5580...
# 3                       2 ingredient5259 ingredient9496
# 4     4 ingredient2857 ingredient9130 ingredient4932...
# ...                                                 ...
# 9967  5 ingredient1508 ingredient233 ingredient3435 ...
# 9968                                   1 ingredient6507
# 9969                                   1 ingredient4160
# 9970     3 ingredient6049 ingredient7794 ingredient3649
# 9971                                    1 ingredient172
#
# [9972 rows x 1 columns]

# %%
df2 = df.copy()
df2 = df2.iloc[df.index%2==1]
df2.columns = ["dislike"]
df2.index = np.arange(len(df2))
df2
# Out:
#                                                 dislike
# 0                                      1 ingredient4654
# 1                       2 ingredient5259 ingredient9496
# 2                       2 ingredient2177 ingredient7332
# 3                                      1 ingredient6321
# 4                       2 ingredient4951 ingredient8544
# ...                                                 ...
# 4981                                                  0
# 4982  5 ingredient1445 ingredient8492 ingredient1390...
# 4983  5 ingredient1508 ingredient233 ingredient3435 ...
# 4984                                   1 ingredient4160
# 4985                                    1 ingredient172
#
# [4986 rows x 1 columns]

# %%
import linecache
import pandas as pd

pl = int(linecache.getline('/content/c_coarse.in.txt', 1))
with open("/content/c_coarse.in.txt",'r') as f:
  list_indi = [[0 for a in range(2)] for b in range(pl)]
  def find_ingerdiants(list_indi):
    a=0
    for i in f:
      a+=1
      if len(i)>2:
        k = i.split()
        if (a%2==0):
          k.pop(0)
          list_indi[(a//2)-1][0]=k
        else:
          k.pop(0)
          list_indi[(a//2)-1][1]=k

  find_ingerdiants(list_indi)
df = pd.DataFrame(list_indi, columns =['like', 'dislike'])
print(df)
# Out:
#                     like  dislike
# 0  [akuof, byyii, dlust]  [xdozp]
# 1  [dlust, luncl, qzfyo]  [xdozp]
# 2  [akuof, luncl, vxglq]  [qzfyo]
# 3  [dlust, vxglq, luncl]        0
# 4  [dlust, xveqd, tfeej]        0
# 5  [qzfyo, vxglq, luncl]  [byyii]
# 6  [luncl, xdozp, xveqd]  [sunhp]
# 7  [byyii, xdozp, tfeej]  [qzfyo]
# 8  [dlust, akuof, tfeej]  [xveqd]
# 9  [vxglq, dlust, byyii]  [akuof]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   like     10 non-null     object
#  1   dislike  10 non-null     object
# dtypes: object(2)
# memory usage: 288.0+ bytes

# %%
print("          ","like","                      ","dislike")

for i in range(0,pl):
  print(list_indi[i][0],"           ",list_indi[i][1])
# Out:
#            like                        dislike
# ['akuof', 'byyii', 'dlust']             ['xdozp']
# ['dlust', 'luncl', 'qzfyo']             ['xdozp']
# ['akuof', 'luncl', 'vxglq']             ['qzfyo']
# ['dlust', 'vxglq', 'luncl']             0
# ['dlust', 'xveqd', 'tfeej']             0
# ['qzfyo', 'vxglq', 'luncl']             ['byyii']
# ['luncl', 'xdozp', 'xveqd']             ['sunhp']
# ['byyii', 'xdozp', 'tfeej']             ['qzfyo']
# ['dlust', 'akuof', 'tfeej']             ['xveqd']
# ['vxglq', 'dlust', 'byyii']             ['akuof']

# %% [markdown]
# df3 = df.copy()
# df3 = df3.iloc[df.index%2==0]
# df3.columns = ["like"]
# df3.index = np.arange(len(df2))
# df3

# %% [markdown]
# # **Simulator**

# %% [markdown]
# like = list_indi[i][0]
#
# dislike = list_indi[i][1]

# %%
import linecache

pl = int(linecache.getline('/content/c_coarse.in.txt', 1))
with open("/content/c_coarse.in.txt",'r') as f:
  list_indi = [[0 for a in range(2)] for b in range(pl)]
  def find_ingerdiants(list_indi):
    a=0
    for i in f:
      a+=1
      if len(i)>2:
        k = i.split()
        if (a%2==0):
          k.pop(0)
          list_indi[(a//2)-1][0]=k
        else:
          k.pop(0)
          list_indi[(a//2)-1][1]=k

  find_ingerdiants(list_indi)
print(list_indi)
# Out:
# [[['akuof', 'byyii', 'dlust'], ['xdozp']], [['dlust', 'luncl', 'qzfyo'], ['xdozp']], [['akuof', 'luncl', 'vxglq'], ['qzfyo']], [['dlust', 'vxglq', 'luncl'], 0], [['dlust', 'xveqd', 'tfeej'], 0], [['qzfyo', 'vxglq', 'luncl'], ['byyii']], [['luncl', 'xdozp', 'xveqd'], ['sunhp']], [['byyii', 'xdozp', 'tfeej'], ['qzfyo']], [['dlust', 'akuof', 'tfeej'], ['xveqd']], [['vxglq', 'dlust', 'byyii'], ['akuof']]]

# %%
file = open("/content/c_coarse.in.txt","r")
total_indi = []
def find_indi(total_indi):

  for i in file:
    if len(i)>2:
      k = i.split()
      for j in k:
        if j.isnumeric()==False:
          if j not in total_indi:
            total_indi.append(j)

find_indi(total_indi)
print(total_indi)
# Out:
# ['akuof', 'byyii', 'dlust', 'xdozp', 'luncl', 'qzfyo', 'vxglq', 'xveqd', 'tfeej', 'sunhp']

# %%
input_file = open("/content/c_Ans.txt","r")
lst = input_file.read().split()
lst.pop(0)
customer=0
for i in range(0,pl):
  a=0
  if list_indi[i][1] != 0:

    for j in range(0,len(list_indi[i][1])):
      if list_indi[i][1][j] in lst:
        a+=1
    if a>0:
      break
  if (set(list_indi[i][0]).issubset(set(lst))):
    customer+=1
print(customer)
# Out:
# 4

# %% [markdown]
# # Final

# %%
import linecache
import pandas as pd


file_name = "/content/e_elaborate.in.txt"

file = open(file_name,"r")
total_indi = []
def find_indi(total_indi):

  for i in file:
    if len(i)>2:
      k = i.split()
      for j in k:
        if len(j)>4:

          if j not in total_indi:
            total_indi.append(j)
find_indi(total_indi)
list_df = pd.DataFrame(total_indi, columns =['Ingredients'])
print(list_df)

pl = int(linecache.getline(file_name, 1))
file = open(file_name,"r")
list_indi = [[0 for a in range(2)] for b in range(pl)]
def data(list_indi):
  a=0
  for i in file:
    a+=1
    if len(i)>2:
      k = i.split()
      if (a%2==0):
        k.pop(0)
        list_indi[(a//2)-1][0]=k
      else:
        k.pop(0)
        list_indi[(a//2)-1][1]=k
data(list_indi)
df = pd.DataFrame(list_indi, columns =['like', 'dislike'])
print(df)
# Out:
#          Ingredients
# 0     ingredient9922
# 1     ingredient3341
# 2     ingredient7670
# 3     ingredient7324
# 4     ingredient9885
# ...              ...
# 9995  ingredient7813
# 9996  ingredient1456
# 9997  ingredient9396
# 9998  ingredient7111
# 9999  ingredient3649
#
# [10000 rows x 1 columns]
#                                                    like                                            dislike
# 0     [ingredient9922, ingredient3341, ingredient767...                                   [ingredient4654]
# 1     [ingredient2920, ingredient1643, ingredient558...                   [ingredient5259, ingredient9496]
# 2     [ingredient2857, ingredient9130, ingredient493...                   [ingredient2177, ingredient7332]
# 3     [ingredient8806, ingredient5320, ingredient569...                                   [ingredient6321]
# 4                       [ingredient697, ingredient8002]                   [ingredient4951, ingredient8544]
# ...

# %% [markdown]
# # **Simulator Final**

# %%
import linecache

input_filename = "/content/e_elaborate.in.txt"
output_filename="Ans.txt"


pl = int(linecache.getline(input_filename, 1))
with open(input_filename,'r') as f:
  list_indi = [[0 for a in range(2)] for b in range(pl)]
  def find_ingerdiants(list_indi):
    a=0
    for i in f:
      a+=1
      if len(i)>2:
        k = i.split()
        if (a%2==0):
          k.pop(0)
          list_indi[(a//2)-1][0]=k
        else:
          k.pop(0)
          list_indi[(a//2)-1][1]=k

  find_ingerdiants(list_indi)

input_file = open(output_filename,"r")
lst = input_file.read().split()
lst.pop(0)

customer=0
for i in range(0,pl):
  a=0

  if list_indi[i][1] != 0:

    for j in range(0,len(list_indi[i][1])):
      if list_indi[i][1][j] in lst:
        a+=1
    if a>0:
      continue
  if (set(list_indi[i][0]).issubset(set(lst))):
    customer+=1

print(customer)
# Out:
# 946

# %%
import itertools
import linecache

input_filename = "/content/d_difficult.in.txt"
file = open(input_filename,"r")
total_indi = []
list_indi=[]
score =0
def find_indi(total_indi):

  for i in file:
    if len(i)>2:
      k = i.split()
      for j in k:
        if j.isnumeric()==False:
          if j not in total_indi:
            total_indi.append(j)

find_indi(total_indi)
pl = int(linecache.getline(input_filename, 1))
with open(input_filename,'r') as f:
  list_indi = [[0 for a in range(2)] for b in range(pl)]
  def data(list_indi):
    a=0
    for i in f:
      a+=1
      if len(i)>2:
        k = i.split()
        if (a%2==0):
          k.pop(0)
          list_indi[(a//2)-1][0]=k
        else:
          k.pop(0)
          list_indi[(a//2)-1][1]=k

  data(list_indi)

all_combinations = []
for r in range(len(total_indi) + 1):
  combinations_object = itertools.combinations(total_indi, r)
  combinations_list = list(combinations_object)
  all_combinations += combinations_list

for i in all_combinations:

  lst=list(i)
  customer=0
  for i in range(0,pl):
    a=0

    if list_indi[i][1] != 0:

      for j in range(0,len(list_indi[i][1])):
        if list_indi[i][1][j] in lst:
          a+=1
      if a>0:
        continue
    if (set(list_indi[i][0]).issubset(set(lst))):
      customer+=1
  score.append(customer)

maxi = max(score)
for i in range(0,len(score)):
  if maxi == score[i]:
    ans = i

print(score[ans],all_combinations[ans])

# %%
import itertools
import linecache

input_filename = "/content/c_coarse.in.txt"
file = open(input_filename,"r")
total_indi = []
list_indi=[]
final_list=[]
score =0

def find_indi(total_indi):

  for i in file:
    if len(i)>2:
      k = i.split()
      for j in k:
        if j.isnumeric()==False:
          if j not in total_indi:
            total_indi.append(j)

find_indi(total_indi)

# %%
pl = int(linecache.getline(input_filename, 1))
with open(input_filename,'r') as f:
  list_indi = [[0 for a in range(2)] for b in range(pl)]
  def data(list_indi):
    a=0
    for i in f:
      a+=1
      if len(i)>2:
        k = i.split()
        if (a%2==0):
          k.pop(0)
          list_indi[(a//2)-1][0]=k
        else:
          k.pop(0)
          list_indi[(a//2)-1][1]=k

  data(list_indi)

# %%
for r in range(len(total_indi) + 1):
  combinations_object = itertools.combinations(total_indi, r)
  combinations_list = list(combinations_object)

  for x in range(1,len(combinations_list)):
    lst=list(combinations_list[x])
    customer=0
    for i in range(0,pl):
      a=0


      if list_indi[i][1] != 0:

        for j in range(0,len(list_indi[i][1])):
          if list_indi[i][1][j] in lst:
            a+=1
        if a>0:
          continue
      if (set(list_indi[i][0]).issubset(set(lst))):
        customer+=1
    if customer>score:
      score = customer
      final_list = list(combinations_list[x])


str = ""
for i in final_list:
  str =  str+" "+i
print(score,len(final_list),str)
# Out:
# 5 7  byyii dlust xdozp luncl vxglq xveqd tfeej

# %% [markdown]
# # **Code-score-popper**

# %%
import linecache

input_filename = "/content/e_elaborate.in.txt"
file = open(input_filename,"r")
total_indi = []
list_indi=[]
final_list=[]
score =0

def find_indi(total_indi):

  for i in file:
    if len(i)>2:
      k = i.split()
      for j in k:
        if j.isnumeric()==False:
          if j not in total_indi:
            total_indi.append(j)

find_indi(total_indi)
print(len(total_indi),total_indi)
# Out:
# 10000 ['ingredient9922', 'ingredient3341', 'ingredient7670', 'ingredient7324', 'ingredient9885', 'ingredient4654', 'ingredient2920', 'ingredient1643', 'ingredient5580', 'ingredient4239', 'ingredient7087', 'ingredient5259', 'ingredient9496', 'ingredient2857', 'ingredient9130', 'ingredient4932', 'ingredient664', 'ingredient2177', 'ingredient7332', 'ingredient8806', 'ingredient5320', 'ingredient569', 'ingredient3724', 'ingredient656', 'ingredient6321', 'ingredient697', 'ingredient8002', 'ingredient4951', 'ingredient8544', 'ingredient3313', 'ingredient1035', 'ingredient6807', 'ingredient2699', 'ingredient717', 'ingredient7199', 'ingredient9038', 'ingredient218', 'ingredient9347', 'ingredient2620', 'ingredient4196', 'ingredient9879', 'ingredient9291', 'ingredient541', 'ingredient8798', 'ingredient2595', 'ingredient4496', 'ingredient6024', 'ingredient6532', 'ingredient3331', 'ingredient2571', 'ingredient5742', 'ingredient8297', 'ingredient2671', 'ingredient9415', 'ingredient9529', 'ingredi
# ...

# %%
pl = int(linecache.getline(input_filename, 1))
with open(input_filename,'r') as f:
  list_indi = [[0 for a in range(2)] for b in range(pl)]
  def data(list_indi):
    a=0
    for i in f:
      a+=1
      if len(i)>2:
        k = i.split()
        if (a%2==0):
          k.pop(0)
          list_indi[(a//2)-1][0]=k
        else:
          k.pop(0)
          list_indi[(a//2)-1][1]=k

  data(list_indi)

# %%
dislike_score=[]
for i in total_indi:
  score_dis = 0
  for j in range(0,pl):
    if list_indi[j][1]==0:
      continue
    for k in list_indi[j][1]:
      if k==i:
        score_dis+=1
  dislike_score.append(score_dis)

# %%
like_score=[]
for i in total_indi:
  score_dis = 0
  for j in range(0,pl):
    if list_indi[j][0]==0:
      continue
    for k in list_indi[j][0]:
      if k==i:
        score_dis+=1
  like_score.append(score_dis)

# %%
n=len(dislike_score)
for i in range(n):
  already_sorted = True
  for j in range(n - i - 1):
    if dislike_score[j] < dislike_score[j + 1]:

      dislike_score[j], dislike_score[j + 1] = dislike_score[j + 1], dislike_score[j]
      total_indi[j], total_indi[j + 1] = total_indi[j + 1], total_indi[j]

      already_sorted = False
  if already_sorted:
    break

# %%
n=len(dislike_score)
for i in range(n):
  already_sorted = True
  for j in range(n - i - 1):
    if like_score[j] == like_score[j+1]:
      if like_score[j] > like_score[j + 1]:

        dislike_score[j], dislike_score[j + 1] = dislike_score[j + 1], dislike_score[j]
        total_indi[j], total_indi[j + 1] = total_indi[j + 1], total_indi[j]

        already_sorted = False
  if already_sorted:
    break

# %%
if dis == dislike_score:
  print("hi")
# Out:
# hi

# %%
x_indi=total_indi

x_score=dislike_score
score = 0
for x in range(0,len(total_indi)):
    print(x)
    lst=x_indi
    customer=0
    for i in range(0,pl):
      a=0


      if list_indi[i][1] != 0:

        for j in range(0,len(list_indi[i][1])):
          if list_indi[i][1][j] in lst:
            a+=1
        if a>0:
          continue
      if (set(list_indi[i][0]).issubset(set(lst))):
        customer+=1

    if customer>score:
      score = customer
      final_list=x_indi.copy()


    x_indi.pop(0)
    x_score.pop(0)
str = ""
for i in final_list:
  str =  str+" "+i
print(score,len(final_list),str)
# Out:
# Streaming output truncated to the last 5000 lines.
# 5001
# 5002
# 5003
# 5004
# 5005
# 5006
# 5007
# 5008
# 5009
# 5010
# 5011
# 5012
# 5013
# 5014
# 5015
# 5016
# 5017
# 5018
# 5019
# 5020
# 5021
# 5022
# 5023
# 5024
# 5025
# 5026
# 5027
# 5028
# 5029
# 5030
# 5031
# 5032
# 5033
# 5034
# 5035
# 5036
# 5037
# 5038
# 5039
# 5040
# 5041
# 5042
# 5043
# 5044
# 5045
# 5046
# 5047
# 5048
# 5049
# 5050
# 5051
# 5052
# 5053
# 5054
# 5055
# 5056
# 5057
# 5058
# 5059
# 5060
# 5061
# 5062
# 5063
# 5064
# 5065
# 5066
# 5067
# 5068
# 5069
# 5070
# 5071
# 5072
# 5073
# 5074
# 5075
# 5076
# 5077
# 5078
# 5079
# 5080
# 5081
# 5082
# 5083
# 5084
# 5085
# 5086
# 5087
# 5088
# 5089
# 5090
# 5091
# 5092
# 5093
# 5094
# 5095
# 5096
# 5097
# 5098
# 5099
# 5100
# 5101
# 5102
# 5103
# 5104
# 5105
# 5106
# 5107
# 5108
# 5109
# 5110
# 5111
# 5112
# 5113
# 5114
# 5115
# 5116
# 5117
# 5118
# 5119
# 5120
# 5121
# 5122
# 5123
# 5124
# 5125
# 5126
# 5127
# 5128
# 5129
# 5130
# 5131
# 5132
# 5133
# 5134
# 5135
# ...

# %%
import linecache

input_filename = "/content/d_difficult.in.txt"
file = open(input_filename,"r")
total_indi = []
list_indi=[]
final_list=[]
score =0

def find_indi(total_indi):

  for i in file:
    if len(i)>2:
      k = i.split()
      for j in k:
        if j.isnumeric()==False:
          if j not in total_indi:
            total_indi.append(j)

find_indi(total_indi)
print(len(total_indi),total_indi)
# Out:
# 600 ['ingredient319', 'ingredient79', 'ingredient123', 'ingredient550', 'ingredient34', 'ingredient478', 'ingredient552', 'ingredient368', 'ingredient169', 'ingredient266', 'ingredient353', 'ingredient359', 'ingredient268', 'ingredient279', 'ingredient246', 'ingredient442', 'ingredient312', 'ingredient434', 'ingredient68', 'ingredient124', 'ingredient304', 'ingredient220', 'ingredient200', 'ingredient452', 'ingredient113', 'ingredient58', 'ingredient494', 'ingredient396', 'ingredient349', 'ingredient518', 'ingredient7', 'ingredient111', 'ingredient251', 'ingredient296', 'ingredient245', 'ingredient339', 'ingredient500', 'ingredient598', 'ingredient14', 'ingredient397', 'ingredient348', 'ingredient250', 'ingredient136', 'ingredient450', 'ingredient211', 'ingredient197', 'ingredient584', 'ingredient27', 'ingredient333', 'ingredient157', 'ingredient323', 'ingredient146', 'ingredient12', 'ingredient47', 'ingredient547', 'ingredient192', 'ingredient263', 'ingredient160', 'ingredient283', 
# ...

# %%
import itertools



combinations_object = itertools.combinations(total_indi, 450)
combinations_list = list(combinations_object)

for x in range(1,len(combinations_list)):
  lst=list(combinations_list[x])
  customer=0
  for i in range(0,pl):
    a=0


    if list_indi[i][1] != 0:

      for j in range(0,len(list_indi[i][1])):
        if list_indi[i][1][j] in lst:
          a+=1
      if a>0:
        continue
    if (set(list_indi[i][0]).issubset(set(lst))):
      customer+=1
  if customer>score:
    score = customer
    final_list = list(combinations_list[x])


str = ""
for i in final_list:
  str =  str+" "+i
print(score,len(final_list),str)
